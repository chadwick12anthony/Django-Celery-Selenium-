# %%
url = 'https://www.amazon.com/PlayStation®5-console-1TB-PlayStation-5/dp/B0FRGTYSL5/ref=sr_1_1?crid=4TI840ZIECF2&dib=eyJ2IjoiMSJ9.ZRn3s4_wnw4qWF_JuLf0hjLor73E6V8iHdyF9Ljioh_oWGC3cnC7KIbMLtE-21_ZBKthrA7h-6UmVSU2OyH5u7_NEeJ_zvKfG-6B1V7wiGCqIX_1XTuxnXzYPz20Z-XNG_CPXogzxXlRVXN1d4TfHETK-3obMC-Y8BYprp5ZlQ-stFAzqHBI0wkhWLi-t5s-OQtrzSvrg6FUuNpHNpQiSRmohSKzJ5C6cecNv6bFVGo.g-8NXks654nINVWEkFP6mRBoE9vRzO-AcYVF8PlccC8&dib_tag=se&keywords=playstation%2B5&qid=1776345683&sprefix=playstat%2Caps%2C400&sr=8-1&th=1'

# %%
from selenium.webdriver import Remote, ChromeOptions
from selenium.webdriver.chromium.remote_connection import ChromiumRemoteConnection

SBR_WEBDRIVER = 'https://brd-customer-hl_4f8a071e-zone-scraping_browser1:c6zsfy7i0386@brd.superproxy.io:9515'


def scrape(url=None):
    print('Connecting to Scraping Browser...')
    sbr_connection = ChromiumRemoteConnection(SBR_WEBDRIVER, 'goog', 'chrome')
    html = ""
    with Remote(sbr_connection, options=ChromeOptions()) as driver:
        print(f'Connected! Navigating to {url}')
        driver.get(url)
        # CAPTCHA handling: If you're expecting a CAPTCHA on the target page, use the following code snippet to check the status of Scraping Browser's automatic CAPTCHA solver
        # print('Waiting captcha to solve...')
        # solve_res = driver.execute('executeCdpCommand', {
        #     'cmd': 'Captcha.waitForSolve',
        #     'params': {'detectTimeout': 10000},
        # })
        # print('Captcha solve status:', solve_res['value']['status'])
        print('Navigated! Scraping page content...')
        html = driver.page_source
    return html

# %%
scrape(url=url)
# Out:
# Connecting to Scraping Browser...
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 scrape(url=url)
#
# Cell In[6], line 11, in scrape(url)
#       7 def scrape(url=None):
#       8     print('Connecting to Scraping Browser...')
#       9     sbr_connection = ChromiumRemoteConnection(SBR_WEBDRIVER, 'goog', 'chrome')
#      10     html = ""
# ---> 11     with Remote(sbr_connection, options=ChromeOptions()) as driver:
#      12         print(f'Connected! Navigating to {url}')
#      13         driver.get(url)
#      14         # CAPTCHA handling: If you're expecting a CAPTCHA on the target page, use the following code snippet to check the status of Scraping Browser's automatic CAPTCHA solver
#
# File ~/Django+Celery+Selenium/venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:274, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     272 self._authenticator_id = None
#     273 self.start_client()
# --> 274 self.start_session(capabilities)
#     275 self._fedcm = FedCM(self)
#     277 self._websocket_connection: WebSocketConnection | None = None
#
# File ~/Django+Celery+Selenium/venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:370, in WebDriver.start_session(self, capabilities)
#     368 caps = _create_caps(capabilities)
#     369 try:
# --> 370     response = self.execute(Command.NEW_SESSION, caps)["value"]
#     371     self.session_id = response.get("sessionId")
#     372     self.caps = response.get("capabilities")
#
# File ~/Django+Celery+Selenium/venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:450, in WebDriver.execute(self, driver_command, params)
#     447 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     449 if response:
# --> 450     self.error_handler.check_response(response)
#     451     response["value"] = self._unwrap_value(response.get("value", None))
#     452     return response
#
# File ~/Django+Celery+Selenium/venv/lib/python3.13/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: Wrong customer name
